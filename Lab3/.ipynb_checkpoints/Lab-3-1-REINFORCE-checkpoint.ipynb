# %% [markdown]
# # Lab 3-1: REINFORCE
#     In this lab, you need to implement a REINFORCE algorithm with Tensorflow and solve OpenAI Gym CartPole-v0

# %%
from cartpole_env import *

import numpy as np
import tensorflow as tf

from collections import namedtuple, deque

# Define the data structure of experience
Experience = namedtuple('Experience', 'state action reward next_state done')

# %% [markdown]
# ## Implement ```discount``` function to compute discounted reward

# %%
def discount(rewards, gamma):
    '''
    param rewards: a rewards numpy array
    param gamma: discount factor
    '''
    discounted_rewards = np.zeros_like(rewards)
    
    # TODO: Calculate discounted rewards
    discounted_rewards = rewards
    s = 0
    for i in reversed(range(len(rewards))):
        #
        # reward = [1, 2, 3]
        # discounted_rewards = [
        #    1 + gamma * 2 + gamma * gamma * 3, 
        #    2 + gamma * 3,
        #    3 ]
        #
        
        s = s * gamma + rewards[i]
        discounted_rewards[i] = s

    return discounted_rewards

# %% [markdown]
# ## Implement ```do_rollout``` function to collect rollout

# %%
def do_rollout(env, policy, render=False):
    '''
    Collect a rollout from env with policy
    
    param env: RL Environment
    param policy: a function parameterized by environment state, return a action
    return a list of (state, action, reward, next_state, done)
    '''
    # Initialize done as False
    done = False
    
    # Reset the environment and get the initial state
    state = env.reset()
    
    # Empty list
    rollout = []
    
    while not done:
        action = policy(state)
        next_state, reward, done, info = env.step(action)
        
        # Render the environment (slow)
        if render:
            env.render()
        
        rollout.append(Experience(state, action, reward, next_state, done))
        state = next_state
        
    return rollout

# %% [markdown]
# ## Implement ```ReinforceAgent``` following ```TODO```

# %%
class ReinforceAgent(object):
    def __init__(self, sess, n_states, n_actions, n_hiddens, lr, gamma):
        '''
        param sess: tf session
        param n_states: dim of states
        param n_actions: dim of actions space
        param n_hiddens: dim of hidden state
        '''
        self.sess = sess
        self.n_states = n_states
        self.n_actions = n_actions
        self.n_hiddens = n_hiddens
        
        # Learning rate
        self.lr = lr
        
        # Discount factor
        self.gamma = gamma
       
        self.state = tf.placeholder(shape=[None, n_states], dtype=tf.float32)
        self.value = tf.placeholder(shape=[None], dtype=tf.float32)
        self.action = tf.placeholder(shape=[None], dtype=tf.int32)
        
        # TODO: Declare 1-st hidden layer
        # Define a fully-connected layer with:
        # input = self.state
        # n_units = self.n_hiddens
        # activation = relu
        # weight_initializer = random_normal(0.0, 0.1)
        # bias_initializer = constant (0.1)
        self.h = tf.layers.dense(
            inputs=self.state,
            units=n_hiddens,   
            activation=tf.nn.relu,
            kernel_initializer=tf.random_normal_initializer(0., .1), 
            bias_initializer=tf.constant_initializer(0.1), 
            name='h')
        
        # Declare 1-st hidden layer
        # Define a fully-connected layer with:
        # input = 1-st hidden layer
        # n_units = self.n_actions
        # activation = relu
        # weight_initializer = random_normal(0.0, 0.1)
        # bias_initializer = constant (0.1)
        self.policy = tf.layers.dense(
            inputs=self.h,
            units=n_actions,    
            activation=tf.nn.relu,  
            kernel_initializer=tf.random_normal_initializer(0., .1), 
            bias_initializer=tf.constant_initializer(0.1),
            name='policy')
        
        self.probs = tf.nn.softmax(self.policy)
        
        # TODO: negative log probability
        neg_log = tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=self.action, logits=self.policy)  
        
        # TODO: policy gradient loss function
        self.loss = tf.reduce_mean(neg_log * self.value)
        
        # Optimizer
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.lr)
        self.train_op = self.optimizer.minimize(self.loss)
        
    def layer(self, inputs, n_input, n_units, activation=tf.nn.relu):
        weights = tf.Variable(
            tf.random_normal([n_input, n_units], mean=0.0, stddev=0.1), name="weights")
        bias = tf.Variable(tf.constant(0.1, shape=[n_units]))
        outputs = activation(tf.matmul(inputs, weights) + bias) 
        
        return outputs
    
    def act(self, s):
        '''
        param s: a np.ndarray with shape [n_batches, n_states]
        return a batch of actions with shape [n_batches,]
        '''
        # TODO: Softmax stochastic policy
        probs = sess.run(self.probs, feed_dict={self.state: s})
        action = np.random.choice(self.n_actions, 1, p=probs[0])
        
        return action
    
    def train(self, rollout):
        '''
        param rollout: a list o
        '''
        states = np.array([np.asarray(e.state) for e in rollout ])
        actions = np.squeeze(np.array([ e.action for e in rollout ]))
        rewards = np.array([ e.reward for e in rollout ])
        discounted_rewards = discount(rewards, gamma=self.gamma)
        
        self.sess.run(self.train_op, feed_dict={self.state: states,
                                                self.action: actions,
                                                self.value: discounted_rewards})

# %%
LR = 0.001
GAMMA = 0.99

sess = tf.InteractiveSession()
env = CartpoleEnvironment()
agent = ReinforceAgent(sess=sess, 
                       n_states=env.observation_space.shape[0],
                       n_actions=env.action_space.n,
                       n_hiddens=20,
                       lr=LR,
                       gamma=GAMMA)
init = tf.global_variables_initializer()
sess.run(init)
# Out:
# [2017-10-19 13:25:46,278] Making new env: CartPole-v0

# %%
def policy(s):
    return agent.act([s])[0]

# %%
def calculate_episode_reward(rollout):
    rewards = [ e.reward for e in rollout ]
    return sum(rewards)

# %%
def eval_history_reward(history):
    arr = np.asarray(history)
    return arr.mean()

# %%
MAX_ITERATIONS = 100000

episode_reward = 0.0
history_episode_rewards = deque(maxlen=100)

plot_history_episode_rewards = []

episode = 0
for iter in range(MAX_ITERATIONS):
    episode = iter
    
    rollout = do_rollout(env=env, policy=policy, render=False)
    agent.train(rollout=rollout)
    
    episode_reward = calculate_episode_reward(rollout)
    history_episode_rewards.append(episode_reward)
    plot_history_episode_rewards.append(episode_reward)
    mean_rewards = eval_history_reward(history_episode_rewards)
    
    print('Episode %d: Reward = %f, Mean reward (over %d episodes) = %f' % (episode, 
                                                                            episode_reward,
                                                                            len(history_episode_rewards),
                                                                            mean_rewards))
    if mean_rewards > 195.0:
        print('Pass')
        break
# Out:
# Episode 0: Reward = -9.000000, Mean reward (over 1 episodes) = -9.000000
# Episode 1: Reward = -10.000000, Mean reward (over 2 episodes) = -9.500000
# Episode 2: Reward = 0.000000, Mean reward (over 3 episodes) = -6.333333
# Episode 3: Reward = -6.000000, Mean reward (over 4 episodes) = -6.250000
# Episode 4: Reward = 30.000000, Mean reward (over 5 episodes) = 1.000000
# Episode 1324: Reward = 200.000000, Mean reward (over 100 episodes) = 189.900000
# Episode 1325: Reward = 200.000000, Mean reward (over 100 episodes) = 189.900000
# Episode 1326: Reward = 200.000000, Mean reward (over 100 episodes) = 190.220000
# Episode 1327: Reward = 200.000000, Mean reward (over 100 episodes) = 190.220000
# Episode 1328: Reward = 200.000000, Mean reward (over 100 episodes) = 190.220000
# Episode 1329: Reward = 200.000000, Mean reward (over 100 episodes) = 190.220000
# Episode 1330: Reward = 200.000000, Mean reward (over 100 episodes) = 190.610000
# Episode 1331: Reward = 160.000000, Mean reward (over 100 episodes) = 190.210000
# Episode 1332: Reward = 200.000000, Mean reward (over 100 episodes) = 191.020000
# Episode 1333: Reward = 200.000000, Mean reward (over 100 episodes) = 191.020000
# Episode 1334: Reward = 200.000000, Mean reward (over 100 episodes) = 191.020000
# Episode 1335: Reward = 200.000000, Mean reward (over 100 episodes) = 191.020000
# Episode 1336: Reward = 200.000000, Mean reward (over 100 episodes) = 191.020000
# Episode 1337: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1338: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1339: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1340: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1341: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1342: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1343: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1344: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1345: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1346: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1347: Reward = 200.000000, Mean reward (over 100 episodes) = 191.370000
# Episode 1348: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1349: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1350: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1351: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1352: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1353: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1354: Reward = 200.000000, Mean reward (over 100 episodes) = 191.910000
# Episode 1355: Reward = 200.000000, Mean reward (over 100 episodes) = 192.580000
# Episode 1356: Reward = 200.000000, Mean reward (over 100 episodes) = 192.800000
# Episode 1357: Reward = 136.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1358: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1359: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1360: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1361: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1362: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1363: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1364: Reward = 200.000000, Mean reward (over 100 episodes) = 192.160000
# Episode 1365: Reward = 111.000000, Mean reward (over 100 episodes) = 191.270000
# Episode 1366: Reward = 200.000000, Mean reward (over 100 episodes) = 191.270000
# Episode 1367: Reward = 200.000000, Mean reward (over 100 episodes) = 191.270000
# Episode 1368: Reward = 200.000000, Mean reward (over 100 episodes) = 191.270000
# Episode 1369: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1370: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1371: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1372: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1373: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1374: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1375: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1376: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1377: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1378: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1379: Reward = 200.000000, Mean reward (over 100 episodes) = 191.930000
# Episode 1380: Reward = 200.000000, Mean reward (over 100 episodes) = 193.230000
# Episode 1381: Reward = 200.000000, Mean reward (over 100 episodes) = 193.230000
# Episode 1382: Reward = 200.000000, Mean reward (over 100 episodes) = 193.230000
# Episode 1383: Reward = 200.000000, Mean reward (over 100 episodes) = 193.800000
# Episode 1384: Reward = 200.000000, Mean reward (over 100 episodes) = 195.500000
# Pass

# %%
import matplotlib.pyplot as plt

def plot(x, y, name):
    fig, ax = plt.subplots()
    ax.plot(x, y)
    
    ax.set(xlabel='Episode', ylabel='Reward', title=name)
    ax.grid()

    fig.savefig("%s.png" % name)
    plt.show()
    
plot(range(episode), plot_history_episode_rewards, 'REINFORCE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-28349582358e> in <module>()
#      11     plt.show()
#      12
# ---> 13 plot(range(episode), plot_history_episode_rewards, 'REINFORCE')
#
# NameError: name 'episode' is not defined

# %%
while True:
    do_rollout(env=env, policy=policy, render=True)
