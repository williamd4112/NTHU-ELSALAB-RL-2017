# %% [markdown]
# # Lab 3-1: REINFORCE
#     In this lab, you need to implement a REINFORCE algorithm with Tensorflow and solve OpenAI Gym CartPole-v0

# %%
from cartpole_env import *

import numpy as np
import tensorflow as tf

from collections import namedtuple, deque

# Define the data structure of experience
Experience = namedtuple('Experience', 'state action reward next_state done')

# %% [markdown]
# ## Implement ```discount``` function to compute discounted reward

# %%
def discount(rewards, gamma):
    '''
    param rewards: a rewards numpy array
    param gamma: discount factor
    '''
    discounted_rewards = np.zeros_like(rewards)
    running_add = 0
    for t in reversed(range(len(rewards))):
        running_add = running_add * gamma + rewards[t]
        discounted_rewards[t] = running_add
    return discounted_rewards

# %% [markdown]
# ## Implement ```do_rollout``` function to collect rollout

# %%
def do_rollout(env, policy, render=False):
    '''
    Collect a rollout from env with policy
    
    param env: RL Environment
    param policy: a function parameterized by environment state, return a action
    return a list of (state, action, reward, next_state, done)
    '''
    # Initialize done as False
    done = False
    
    # Reset the environment and get the initial state
    state = env.reset()
    
    # Empty list
    rollout = []
    
    while not done:
        action = policy(state)
        next_state, reward, done, info = env.step(action)
        
        # Render the environment (slow)
        if render:
            env.render()
        
        rollout.append(Experience(state, action, reward, next_state, done))
        state = next_state
        
    return rollout

# %% [markdown]
# ## Implement ```ReinforceAgent``` following ```TODO```

# %%
class ReinforceAgent(object):
    def __init__(self, sess, n_states, n_actions, n_hiddens, lr, gamma):
        '''
        param sess: tf session
        param n_states: dim of states
        param n_actions: dim of actions space
        param n_hiddens: dim of hidden state
        '''
        self.sess = sess
        self.n_states = n_states
        self.n_actions = n_actions
        
        # Learning rate
        self.lr = lr
        
        # Discount factor
        self.gamma = gamma
       
        self.state = tf.placeholder(shape=[None, n_states], dtype=tf.float32)
        self.value = tf.placeholder(shape=[None], dtype=tf.float32)
        self.action = tf.placeholder(shape=[None], dtype=tf.int32)
        
        # Declare 1-st hidden layer
        # Define a fully-connected layer with:
        # input = self.state
        # n_units = self.n_hiddens
        # activation = relu
        # weight_initializer = random_normal(0.0, 0.1)
        # bias_initializer = constant (0.1)
        self.h = tf.layers.dense(
                inputs=self.state,
                units=n_hiddens,   
                activation=tf.nn.relu,
                kernel_initializer=tf.random_normal_initializer(0., .1), 
                bias_initializer=tf.constant_initializer(0.1), 
                name='h')
        
        # Declare 1-st hidden layer
        # Define a fully-connected layer with:
        # input = 1-st hidden layer
        # n_units = self.n_actions
        # activation = relu
        # weight_initializer = random_normal(0.0, 0.1)
        # bias_initializer = constant (0.1)
        self.policy = tf.layers.dense(
                inputs=self.h,
                units=n_actions,    
                activation=tf.nn.softmax,  
                kernel_initializer=tf.random_normal_initializer(0., .1), 
                bias_initializer=tf.constant_initializer(0.1),
                name='policy')
        
        # negative log probability 
        neglog_prob = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=self.policy, labels=self.action)
         
        # TODO: policy gradient loss function
        self.loss = tf.reduce_mean(neglog_prob * self.value) 
        
        # TODO: Optimizer
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.lr)
        self.train_op = self.optimizer.minimize(self.loss)
        
    def act(self, s):
        '''
        param s: a np.ndarray with shape [n_batches, n_states]
        return a batch of actions with shape [n_batches,]
        '''
        policy = self.sess.run(self.policy, feed_dict={self.state: s})
        return np.array([np.random.choice(range(self.n_actions), p=p) for p in policy])
    
    def train(self, rollout):
        '''
        param rollout: a list o
        '''
        states = np.array([ np.asarray(e.state) for e in rollout ])
        actions = np.squeeze(np.array([ e.action for e in rollout ]))
        rewards = np.array([ e.reward for e in rollout ])
        discounted_rewards = discount(rewards, gamma=self.gamma)
        
        self.sess.run(self.train_op, feed_dict={self.state: states,
                                                self.action: actions,
                                                self.value: discounted_rewards})

# %%
LR = 0.001
GAMMA = 0.99

sess = tf.InteractiveSession()
env = CartpoleEnvironment()
agent = ReinforceAgent(sess=sess, 
                       n_states=env.observation_space.shape[0],
                       n_actions=env.action_space.n,
                       n_hiddens=20,
                       lr=LR,
                       gamma=GAMMA)
init = tf.global_variables_initializer()
sess.run(init)
# Out:
# [2017-10-16 18:24:02,574] Making new env: CartPole-v0

# %%
def policy(s):
    return agent.act([s])[0]

# %%
def calculate_episode_reward(rollout):
    rewards = [ e.reward for e in rollout ]
    return sum(rewards)

# %%
def eval_history_reward(history):
    arr = np.asarray(history)
    return arr.mean()

# %%
MAX_ITERATIONS = 100000

episode_reward = 0.0
history_episode_rewards = deque(maxlen=100)

plot_history_episode_rewards = []

for iter in range(MAX_ITERATIONS):
    rollout = do_rollout(env=env, policy=policy, render=False)
    agent.train(rollout=rollout)
    
    episode_reward = calculate_episode_reward(rollout)
    history_episode_rewards.append(episode_reward)
    plot_history_episode_rewards.append(episode_reward)
    mean_rewards = eval_history_reward(history_episode_rewards)
    
    print('Episode %d: Reward = %f, Mean reward (over %d episodes) = %f' % (iter, 
                                                                            episode_reward,
                                                                            len(history_episode_rewards),
                                                                            mean_rewards))
    if mean_rewards > 195.0:
        print('Pass')
        break
# Out:
# Episode 0: Reward = -6.000000, Mean reward (over 1 episodes) = -6.000000
# Episode 1: Reward = -10.000000, Mean reward (over 2 episodes) = -8.000000
# Episode 2: Reward = 2.000000, Mean reward (over 3 episodes) = -4.666667
# Episode 3: Reward = 1.000000, Mean reward (over 4 episodes) = -3.250000
# Episode 4: Reward = -8.000000, Mean reward (over 5 episodes) = -4.200000
# Episode 5: Reward = -4.000000, Mean reward (over 6 episodes) = -4.166667
# Episode 6: Reward = 17.000000, Mean reward (over 7 episodes) = -1.142857
# Episode 7: Reward = -2.000000, Mean reward (over 8 episodes) = -1.250000
# Episode 8: Reward = 4.000000, Mean reward (over 9 episodes) = -0.666667
# Episode 9: Reward = -9.000000, Mean reward (over 10 episodes) = -1.500000
# Episode 10: Reward = -7.000000, Mean reward (over 11 episodes) = -2.000000
# Episode 11: Reward = -6.000000, Mean reward (over 12 episodes) = -2.333333
# Episode 12: Reward = 75.000000, Mean reward (over 13 episodes) = 3.615385
# Episode 13: Reward = -6.000000, Mean reward (over 14 episodes) = 2.928571
# Episode 14: Reward = -4.000000, Mean reward (over 15 episodes) = 2.466667
# Episode 15: Reward = 6.000000, Mean reward (over 16 episodes) = 2.687500
# Episode 16: Reward = 23.000000, Mean reward (over 17 episodes) = 3.882353
# Episode 17: Reward = 11.000000, Mean reward (over 18 episodes) = 4.277778
# Episode 26326: Reward = 117.000000, Mean reward (over 100 episodes) = 130.080000
# Episode 26327: Reward = 138.000000, Mean reward (over 100 episodes) = 130.310000
# Episode 26328: Reward = 132.000000, Mean reward (over 100 episodes) = 130.140000
# Episode 26329: Reward = 106.000000, Mean reward (over 100 episodes) = 130.090000
# Episode 26330: Reward = 135.000000, Mean reward (over 100 episodes) = 130.020000
# Episode 26331: Reward = 113.000000, Mean reward (over 100 episodes) = 129.690000
# Episode 26332: Reward = 138.000000, Mean reward (over 100 episodes) = 129.670000
# Episode 26333: Reward = 133.000000, Mean reward (over 100 episodes) = 129.960000
# Episode 26334: Reward = 114.000000, Mean reward (over 100 episodes) = 129.950000
# Episode 26335: Reward = 127.000000, Mean reward (over 100 episodes) = 129.760000
# Episode 26336: Reward = 157.000000, Mean reward (over 100 episodes) = 130.050000
# Episode 26337: Reward = 129.000000, Mean reward (over 100 episodes) = 130.140000
# Episode 26338: Reward = 150.000000, Mean reward (over 100 episodes) = 130.380000
# Episode 26339: Reward = 119.000000, Mean reward (over 100 episodes) = 130.270000
# Episode 26340: Reward = 126.000000, Mean reward (over 100 episodes) = 130.180000
# Episode 26341: Reward = 118.000000, Mean reward (over 100 episodes) = 129.920000
# Episode 26342: Reward = 122.000000, Mean reward (over 100 episodes) = 129.620000
# Episode 26343: Reward = 149.000000, Mean reward (over 100 episodes) = 129.720000
# Episode 26344: Reward = 129.000000, Mean reward (over 100 episodes) = 129.840000
# Episode 26345: Reward = 127.000000, Mean reward (over 100 episodes) = 129.890000
# Episode 26346: Reward = 122.000000, Mean reward (over 100 episodes) = 130.060000
# Episode 26347: Reward = 121.000000, Mean reward (over 100 episodes) = 130.150000
# Episode 26348: Reward = 156.000000, Mean reward (over 100 episodes) = 130.480000
# Episode 26349: Reward = 144.000000, Mean reward (over 100 episodes) = 130.400000
# Episode 26350: Reward = 113.000000, Mean reward (over 100 episodes) = 130.440000
# Episode 26351: Reward = 135.000000, Mean reward (over 100 episodes) = 130.390000
# Episode 26352: Reward = 161.000000, Mean reward (over 100 episodes) = 130.920000
# Episode 26353: Reward = 126.000000, Mean reward (over 100 episodes) = 131.050000
# Episode 26354: Reward = 102.000000, Mean reward (over 100 episodes) = 130.800000
# Episode 26355: Reward = 115.000000, Mean reward (over 100 episodes) = 130.760000
# Episode 26356: Reward = 129.000000, Mean reward (over 100 episodes) = 130.680000
# Episode 26357: Reward = 106.000000, Mean reward (over 100 episodes) = 130.250000
# Episode 26358: Reward = 138.000000, Mean reward (over 100 episodes) = 130.090000
# Episode 26359: Reward = 144.000000, Mean reward (over 100 episodes) = 130.040000
# Episode 26360: Reward = 108.000000, Mean reward (over 100 episodes) = 129.760000
# Episode 26361: Reward = 127.000000, Mean reward (over 100 episodes) = 129.890000
# Episode 26362: Reward = 151.000000, Mean reward (over 100 episodes) = 130.280000
# Episode 26363: Reward = 137.000000, Mean reward (over 100 episodes) = 130.410000
# Episode 26364: Reward = 121.000000, Mean reward (over 100 episodes) = 130.380000
# Episode 26365: Reward = 164.000000, Mean reward (over 100 episodes) = 130.640000
# Episode 26366: Reward = 127.000000, Mean reward (over 100 episodes) = 130.670000
# Episode 26367: Reward = 141.000000, Mean reward (over 100 episodes) = 130.600000
# Episode 26368: Reward = 135.000000, Mean reward (over 100 episodes) = 130.660000
# Episode 26369: Reward = 125.000000, Mean reward (over 100 episodes) = 130.760000
# Episode 26370: Reward = 100.000000, Mean reward (over 100 episodes) = 130.430000
# Episode 26371: Reward = 127.000000, Mean reward (over 100 episodes) = 130.300000
# Episode 26372: Reward = 107.000000, Mean reward (over 100 episodes) = 129.890000
# Episode 26373: Reward = 121.000000, Mean reward (over 100 episodes) = 130.070000
# Episode 26374: Reward = 142.000000, Mean reward (over 100 episodes) = 130.340000
# Episode 26375: Reward = 131.000000, Mean reward (over 100 episodes) = 130.520000
# Episode 26376: Reward = 109.000000, Mean reward (over 100 episodes) = 130.450000
# Episode 26377: Reward = 123.000000, Mean reward (over 100 episodes) = 130.320000
# Episode 26378: Reward = 126.000000, Mean reward (over 100 episodes) = 130.170000
# Episode 26379: Reward = 139.000000, Mean reward (over 100 episodes) = 130.250000
# Episode 26380: Reward = 117.000000, Mean reward (over 100 episodes) = 130.250000
# Episode 26381: Reward = 161.000000, Mean reward (over 100 episodes) = 130.640000
# Episode 26382: Reward = 111.000000, Mean reward (over 100 episodes) = 130.430000
# Episode 26383: Reward = 113.000000, Mean reward (over 100 episodes) = 130.390000
# Episode 26384: Reward = 149.000000, Mean reward (over 100 episodes) = 130.600000
# Episode 26385: Reward = 155.000000, Mean reward (over 100 episodes) = 130.980000
# Episode 26386: Reward = 120.000000, Mean reward (over 100 episodes) = 130.880000
# Episode 26387: Reward = 142.000000, Mean reward (over 100 episodes) = 130.920000
# Episode 26388: Reward = 147.000000, Mean reward (over 100 episodes) = 131.180000
# Episode 26389: Reward = 132.000000, Mean reward (over 100 episodes) = 131.420000
# Episode 26390: Reward = 121.000000, Mean reward (over 100 episodes) = 131.030000
# Episode 26391: Reward = 157.000000, Mean reward (over 100 episodes) = 131.110000
# Episode 26392: Reward = 142.000000, Mean reward (over 100 episodes) = 131.300000
# Episode 26393: Reward = 130.000000, Mean reward (over 100 episodes) = 131.320000
# Episode 26394: Reward = 151.000000, Mean reward (over 100 episodes) = 131.670000
# Episode 26395: Reward = 127.000000, Mean reward (over 100 episodes) = 131.790000
# Episode 26396: Reward = 115.000000, Mean reward (over 100 episodes) = 131.820000
# Episode 26397: Reward = 127.000000, Mean reward (over 100 episodes) = 131.900000
# Episode 26398: Reward = 200.000000, Mean reward (over 100 episodes) = 132.360000
# Episode 26399: Reward = 116.000000, Mean reward (over 100 episodes) = 132.190000
# Episode 26400: Reward = 128.000000, Mean reward (over 100 episodes) = 132.060000
# Episode 26401: Reward = 137.000000, Mean reward (over 100 episodes) = 132.000000
# Episode 26402: Reward = 111.000000, Mean reward (over 100 episodes) = 131.790000
# Episode 26403: Reward = 135.000000, Mean reward (over 100 episodes) = 131.970000
# Episode 26404: Reward = 110.000000, Mean reward (over 100 episodes) = 131.970000
# Episode 26405: Reward = 137.000000, Mean reward (over 100 episodes) = 132.040000
# Episode 26406: Reward = 101.000000, Mean reward (over 100 episodes) = 131.610000
# Episode 26407: Reward = 131.000000, Mean reward (over 100 episodes) = 131.700000
# Episode 26408: Reward = 116.000000, Mean reward (over 100 episodes) = 131.310000
# Episode 26409: Reward = 108.000000, Mean reward (over 100 episodes) = 130.930000
# Episode 26410: Reward = 109.000000, Mean reward (over 100 episodes) = 130.670000
# Episode 26411: Reward = 138.000000, Mean reward (over 100 episodes) = 130.720000
# Episode 26412: Reward = 121.000000, Mean reward (over 100 episodes) = 130.680000
# Episode 26413: Reward = 116.000000, Mean reward (over 100 episodes) = 130.110000
# Episode 26414: Reward = 123.000000, Mean reward (over 100 episodes) = 130.070000
# Episode 26415: Reward = 133.000000, Mean reward (over 100 episodes) = 130.050000
# Episode 26416: Reward = 120.000000, Mean reward (over 100 episodes) = 129.640000
# Episode 26417: Reward = 123.000000, Mean reward (over 100 episodes) = 129.450000
# Episode 26418: Reward = 106.000000, Mean reward (over 100 episodes) = 129.050000
# Episode 26419: Reward = 110.000000, Mean reward (over 100 episodes) = 128.530000
# Episode 26420: Reward = 127.000000, Mean reward (over 100 episodes) = 128.370000
# Episode 26421: Reward = 126.000000, Mean reward (over 100 episodes) = 128.310000
# Episode 26422: Reward = 131.000000, Mean reward (over 100 episodes) = 128.530000
# Episode 26423: Reward = 146.000000, Mean reward (over 100 episodes) = 128.590000
# Episode 26424: Reward = 117.000000, Mean reward (over 100 episodes) = 128.570000
# Episode 26425: Reward = 142.000000, Mean reward (over 100 episodes) = 128.870000
# Episode 26426: Reward = 132.000000, Mean reward (over 100 episodes) = 129.020000
# Episode 26427: Reward = 137.000000, Mean reward (over 100 episodes) = 129.010000
# Episode 26428: Reward = 154.000000, Mean reward (over 100 episodes) = 129.230000
# Episode 26429: Reward = 163.000000, Mean reward (over 100 episodes) = 129.800000
# Episode 26430: Reward = 103.000000, Mean reward (over 100 episodes) = 129.480000
# Episode 26431: Reward = 108.000000, Mean reward (over 100 episodes) = 129.430000
# Episode 26432: Reward = 105.000000, Mean reward (over 100 episodes) = 129.100000
# Episode 26433: Reward = 136.000000, Mean reward (over 100 episodes) = 129.130000
# Episode 26434: Reward = 143.000000, Mean reward (over 100 episodes) = 129.420000
# Episode 26435: Reward = 157.000000, Mean reward (over 100 episodes) = 129.720000
# Episode 26436: Reward = 123.000000, Mean reward (over 100 episodes) = 129.380000
# Episode 26437: Reward = 149.000000, Mean reward (over 100 episodes) = 129.580000
# Episode 26438: Reward = 136.000000, Mean reward (over 100 episodes) = 129.440000
# Episode 26439: Reward = 123.000000, Mean reward (over 100 episodes) = 129.480000
# Episode 26440: Reward = 112.000000, Mean reward (over 100 episodes) = 129.340000
# Episode 26441: Reward = 116.000000, Mean reward (over 100 episodes) = 129.320000
# Episode 26442: Reward = 122.000000, Mean reward (over 100 episodes) = 129.320000
# Episode 26443: Reward = 115.000000, Mean reward (over 100 episodes) = 128.980000
# Episode 26444: Reward = 123.000000, Mean reward (over 100 episodes) = 128.920000
# Episode 26445: Reward = 150.000000, Mean reward (over 100 episodes) = 129.150000
# Episode 26446: Reward = 122.000000, Mean reward (over 100 episodes) = 129.150000
# Episode 26447: Reward = 135.000000, Mean reward (over 100 episodes) = 129.290000
# Episode 26448: Reward = 200.000000, Mean reward (over 100 episodes) = 129.730000
# Episode 26449: Reward = 116.000000, Mean reward (over 100 episodes) = 129.450000
# Episode 26450: Reward = 145.000000, Mean reward (over 100 episodes) = 129.770000
# Episode 26451: Reward = 117.000000, Mean reward (over 100 episodes) = 129.590000
# Episode 26452: Reward = 126.000000, Mean reward (over 100 episodes) = 129.240000
# Episode 26453: Reward = 200.000000, Mean reward (over 100 episodes) = 129.980000
# Episode 26454: Reward = 138.000000, Mean reward (over 100 episodes) = 130.340000
# Episode 26455: Reward = 113.000000, Mean reward (over 100 episodes) = 130.320000
# Episode 26456: Reward = 143.000000, Mean reward (over 100 episodes) = 130.460000
# Episode 26457: Reward = 134.000000, Mean reward (over 100 episodes) = 130.740000
# Episode 26458: Reward = 122.000000, Mean reward (over 100 episodes) = 130.580000
# Episode 26459: Reward = 125.000000, Mean reward (over 100 episodes) = 130.390000
# Episode 26460: Reward = 144.000000, Mean reward (over 100 episodes) = 130.750000
# Episode 26461: Reward = 129.000000, Mean reward (over 100 episodes) = 130.770000
# Episode 26462: Reward = 135.000000, Mean reward (over 100 episodes) = 130.610000
# Episode 26463: Reward = 143.000000, Mean reward (over 100 episodes) = 130.670000
# Episode 26464: Reward = 142.000000, Mean reward (over 100 episodes) = 130.880000
# Episode 26465: Reward = 112.000000, Mean reward (over 100 episodes) = 130.360000
# Episode 26466: Reward = 131.000000, Mean reward (over 100 episodes) = 130.400000
# Episode 26467: Reward = 134.000000, Mean reward (over 100 episodes) = 130.330000
# Episode 26468: Reward = 120.000000, Mean reward (over 100 episodes) = 130.180000
# Episode 26469: Reward = 127.000000, Mean reward (over 100 episodes) = 130.200000
# Episode 26470: Reward = 139.000000, Mean reward (over 100 episodes) = 130.590000
# Episode 26471: Reward = 200.000000, Mean reward (over 100 episodes) = 131.320000
# Episode 26472: Reward = 137.000000, Mean reward (over 100 episodes) = 131.620000
# Episode 26473: Reward = 118.000000, Mean reward (over 100 episodes) = 131.590000
# Episode 26474: Reward = 126.000000, Mean reward (over 100 episodes) = 131.430000
# Episode 26475: Reward = 124.000000, Mean reward (over 100 episodes) = 131.360000
# Episode 26476: Reward = 138.000000, Mean reward (over 100 episodes) = 131.650000
# Episode 26477: Reward = 145.000000, Mean reward (over 100 episodes) = 131.870000
# Episode 26478: Reward = 103.000000, Mean reward (over 100 episodes) = 131.640000
# Episode 26479: Reward = 115.000000, Mean reward (over 100 episodes) = 131.400000
# Episode 26480: Reward = 143.000000, Mean reward (over 100 episodes) = 131.660000
# Episode 26481: Reward = 124.000000, Mean reward (over 100 episodes) = 131.290000
# Episode 26482: Reward = 154.000000, Mean reward (over 100 episodes) = 131.720000
# Episode 26483: Reward = 130.000000, Mean reward (over 100 episodes) = 131.890000
# Episode 26484: Reward = 170.000000, Mean reward (over 100 episodes) = 132.100000
# Episode 26485: Reward = 125.000000, Mean reward (over 100 episodes) = 131.800000
# Episode 26486: Reward = 124.000000, Mean reward (over 100 episodes) = 131.840000
# Episode 26487: Reward = 106.000000, Mean reward (over 100 episodes) = 131.480000
# Episode 26488: Reward = 123.000000, Mean reward (over 100 episodes) = 131.240000
# Episode 26489: Reward = 128.000000, Mean reward (over 100 episodes) = 131.200000
# Episode 26490: Reward = 124.000000, Mean reward (over 100 episodes) = 131.230000
# Episode 26491: Reward = 104.000000, Mean reward (over 100 episodes) = 130.700000
# Episode 26492: Reward = 103.000000, Mean reward (over 100 episodes) = 130.310000
# Episode 26493: Reward = 136.000000, Mean reward (over 100 episodes) = 130.370000
# Episode 26494: Reward = 105.000000, Mean reward (over 100 episodes) = 129.910000
# Episode 26495: Reward = 143.000000, Mean reward (over 100 episodes) = 130.070000
# Episode 26496: Reward = 121.000000, Mean reward (over 100 episodes) = 130.130000
# Episode 26497: Reward = 155.000000, Mean reward (over 100 episodes) = 130.410000
# Episode 26498: Reward = 127.000000, Mean reward (over 100 episodes) = 129.680000
# Episode 26499: Reward = 125.000000, Mean reward (over 100 episodes) = 129.770000
# Episode 26500: Reward = 126.000000, Mean reward (over 100 episodes) = 129.750000
# Episode 26501: Reward = 129.000000, Mean reward (over 100 episodes) = 129.670000
# Episode 26502: Reward = 124.000000, Mean reward (over 100 episodes) = 129.800000
# Episode 26503: Reward = 155.000000, Mean reward (over 100 episodes) = 130.000000
# Episode 26504: Reward = 129.000000, Mean reward (over 100 episodes) = 130.190000
# Episode 26505: Reward = 126.000000, Mean reward (over 100 episodes) = 130.080000
# Episode 26506: Reward = 121.000000, Mean reward (over 100 episodes) = 130.280000
# Episode 26507: Reward = 115.000000, Mean reward (over 100 episodes) = 130.120000
# Episode 26508: Reward = 143.000000, Mean reward (over 100 episodes) = 130.390000
# Episode 26509: Reward = 126.000000, Mean reward (over 100 episodes) = 130.570000
# Episode 26510: Reward = 120.000000, Mean reward (over 100 episodes) = 130.680000
# Episode 26511: Reward = 135.000000, Mean reward (over 100 episodes) = 130.650000
# Episode 26512: Reward = 147.000000, Mean reward (over 100 episodes) = 130.910000
# Episode 26513: Reward = 138.000000, Mean reward (over 100 episodes) = 131.130000
# Episode 26514: Reward = 126.000000, Mean reward (over 100 episodes) = 131.160000
# Episode 26515: Reward = 129.000000, Mean reward (over 100 episodes) = 131.120000
# Episode 26516: Reward = 106.000000, Mean reward (over 100 episodes) = 130.980000
# Episode 26517: Reward = 121.000000, Mean reward (over 100 episodes) = 130.960000
# Episode 26518: Reward = 111.000000, Mean reward (over 100 episodes) = 131.010000
# Episode 26519: Reward = 127.000000, Mean reward (over 100 episodes) = 131.180000
# Episode 26520: Reward = 126.000000, Mean reward (over 100 episodes) = 131.170000

# %%
import matplotlib.pyplot as plt

def plot(x, y, name):
    fig, ax = plt.subplots()
    ax.plot(x, y)
    
    ax.set(xlabel='Episode', ylabel='Reward', title=name)
    ax.grid()

    fig.savefig("%s.png" % name)
    plt.show()
    
plot(range(episode), plot_history_episode_rewards, 'REINFORCE')

# %%
while True:
    do_rollout(env=env, policy=policy, render=True)
